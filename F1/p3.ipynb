# %% [markdown]
# <a href="https://colab.research.google.com/github/mamathad-ctrl/PYTHON-PROJECT/blob/main/F1/p3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
PRINT("hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_600/1890839294.py in <cell line: 0>()
# ----> 1 PRINT("hello")
#
# NameError: name 'PRINT' is not defined

# %%
print(2+9)
# Out:
# 11
